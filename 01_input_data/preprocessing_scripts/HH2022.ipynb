# %% [markdown]
# *NEED TO WORK ON*

# %%
import sys
import os
import pandas as pd
import numpy as np
from Bio import SeqIO
import re

# %%
dataset = 'HH2022'

print('Loading raw data for', dataset, '...')
data = pd.read_csv('/Users/maryamkoddus/Documents/maryam-ko-QMUL-MSc-Project/01_input_data/raw_data/41598_2022_8430_MOESM12_ESM.csv', header=0)
print('Raw data loaded.')
data
# Out:
# Loading raw data for HH2022 ...
# Raw data loaded.
#         Evidence IDs          Phosphosite IDs Leading Proteins Gene Names  \
# 0                  0  13593;13594;13595;19565           Q9NQS7     INCENP
# 1                  1  13593;13594;13595;19565           Q9NQS7     INCENP
# 2                  2  13593;13594;13595;19565           Q9NQS7     INCENP
# 3                  3  13593;13594;13595;19565           Q9NQS7     INCENP
# 4                  4  13593;13594;13595;19565           Q9NQS7     INCENP
# ...              ...                      ...              ...        ...
# 165472        165472                    13863           Q9NW97     TMEM51
# 165473        165473                    13863           Q9NW97     TMEM51
# 165474        165474                    13863           Q9NW97     TMEM51
# 165475        165475                    13863           Q9NW97     TMEM51
# 165476        165476                    13863           Q9NW97     TMEM51
#
#                             Sequence  Length                  Modifications  \
# 0       AAAAAAAATMALAAPSSPTPESPTMLTK      28    Oxidation (M),Phospho (STY)
# 1       AAAAAAAATMALAAPSSPTPESPTMLTK      28    Oxidation (M),Phospho (STY)
# 2       AAAAAAAATMALAAPSSPTPESPTMLTK      28                  Phospho (STY)
# 3       AAAAAAAATMALAAPSSPTPESPTMLTK      28                  Phospho (STY)
# 4       AAAAAAAATMALAAPSSPTPESPTMLTK      28  2 Oxidation (M),Phospho (STY)
# ...                              ...     ...                            ...
# 165472            YYVPSYEEVMNTNYSEAR      18    Oxidation (M),Phospho (STY)
# 165473            YYVPSYEEVMNTNYSEAR      18    Oxidation (M),Phospho (STY)
# 165474            YYVPSYEEVMNTNYSEAR      18    Oxidation (M),Phospho (STY)
# 165475            YYVPSYEEVMNTNYSEAR      18                  Phospho (STY)
# 165476            YYVPSYEEVMNTNYSEAR      18                  Phospho (STY)
#
#                                  Modified sequence  \
# 0           _AAAAAAAATMALAAPS(ph)SPTPESPTM(ox)LTK_
# 1           _AAAAAAAATMALAAPS(ph)SPTPESPTM(ox)LTK_
# 2               _AAAAAAAATMALAAPS(ph)SPTPESPTMLTK_
# 3               _AAAAAAAATMALAAPS(ph)SPTPESPTMLTK_
# 4       _AAAAAAAATM(ox)ALAAPS(ph)SPTPESPTM(ox)LTK_
# ...                                            ...
# 165472                _YYVPS(ph)YEEVM(ox)NTNYSEAR_
# 165473                _YYVPS(ph)YEEVM(ox)NTNYSEAR_
# 165474                _YYVPS(ph)YEEVM(ox)NTNYSEAR_
# 165475                    _YYVPS(ph)YEEVMNTNYSEAR_
# 165476                    _YYVPS(ph)YEEVMNTNYSEAR_
#
#                        Oxidation (M) Probabilities  \
# 0       AAAAAAAATM(0.022)ALAAPSSPTPESPTM(0.978)LTK
# 1       AAAAAAAATM(0.049)ALAAPSSPTPESPTM(0.951)LTK
# 2                                              NaN
# 3                                              NaN
# 4               AAAAAAAATM(1)ALAAPSSPTPESPTM(1)LTK
# ...                                            ...
# 165472                       YYVPSYEEVM(1)NTNYSEAR
# 165473                       YYVPSYEEVM(1)NTNYSEAR
# 165474                       YYVPSYEEVM(1)NTNYSEAR
# 165475                                         NaN
# 165476                                         NaN
#
#                               Phospho (STY) Probabilities  ...  \
# 0       AAAAAAAAT(0.003)MALAAPS(0.303)S(0.303)PT(0.303...  ...
# 1       AAAAAAAAT(0.003)MALAAPS(0.304)S(0.304)PT(0.304...  ...
# 2       AAAAAAAAT(0.008)MALAAPS(0.425)S(0.425)PT(0.124...  ...
# 3       AAAAAAAAT(0.003)MALAAPS(0.288)S(0.288)PT(0.288...  ...
# 4       AAAAAAAATMALAAPS(0.325)S(0.325)PT(0.325)PES(0....  ...
# ...                                                   ...  ...
# 165472  Y(0.006)Y(0.006)VPS(0.931)Y(0.057)EEVMNT(0.001...  ...
# 165473     Y(0.001)Y(0.001)VPS(0.952)Y(0.047)EEVMNTNYSEAR  ...
# 165474     Y(0.008)Y(0.008)VPS(0.839)Y(0.145)EEVMNTNYSEAR  ...
# 165475     Y(0.003)Y(0.003)VPS(0.822)Y(0.172)EEVMNTNYSEAR  ...
# 165476                   YYVPS(0.956)Y(0.043)EEVMNTNYSEAR  ...
#
#         Reporter intensity 2  Reporter intensity 3  Reporter intensity 4  \
# 0                    16835.0               16028.0                  0.00
# 1                    11121.0               10992.0                648.59
# 2                    11061.0               13143.0                  0.00
# 3                    10076.0               10433.0               3426.60
# 4                    15124.0               15420.0                253.76
# ...                      ...                   ...                   ...
# 165472               18551.0               20730.0              15898.00
# 165473               19759.0               20859.0                  0.00
# 165474               23503.0               25199.0                  0.00
# 165475               12115.0               12867.0               2475.60
# 165476               15901.0               13102.0                  0.00
#
#         Reporter intensity 5  Reporter intensity 6  Reporter intensity 7  \
# 0                       0.00                  0.00                   0.0
# 1                       0.00               1057.60                   0.0
# 2                       0.00               1116.30                   0.0
# 3                     507.41               1465.00                2967.9
# 4                    2105.20                  0.00                1054.0
# ...                      ...                   ...                   ...
# 165472               3334.50               7259.30               11527.0
# 165473               1910.30                  0.00                   0.0
# 165474                339.41                  0.00                   0.0
# 165475               1366.80                879.97                2017.5
# 165476                716.49                  0.00                   0.0
#
#         Reporter intensity 8  Reporter intensity 9  Unnamed: 25
# 0                       0.00                1347.1          NaN NaN
# 1                       0.00                3338.3          NaN NaN
# 2                       0.00                1156.9          NaN NaN
# 3                    2213.90                2013.1          NaN NaN
# 4                    1087.00                   0.0          NaN NaN
# ...                      ...                   ...          ...  ..
# 165472               8817.70                4230.9          NaN NaN
# 165473                954.29                   0.0          NaN NaN
# 165474                  0.00                1082.8          NaN NaN
# 165475               2357.70                1418.2          NaN NaN
# 165476                  0.00                   0.0          NaN NaN
#
# [165477 rows x 27 columns]

# %%
filtered_data = data[data['Modifications'].str.contains(r'^Phospho \(STY\)$', case=False, na=False)]
data = filtered_data[filtered_data['Modifications'].str.count(',') == 0]

print(data[['Gene Names', 'Modifications', 'Modified sequence']])
# Out:
#        Gene Names  Modifications                   Modified sequence
# 2          INCENP  Phospho (STY)  _AAAAAAAATMALAAPS(ph)SPTPESPTMLTK_
# 3          INCENP  Phospho (STY)  _AAAAAAAATMALAAPS(ph)SPTPESPTMLTK_
# 9           SAMD1  Phospho (STY)          _AAAAAATAPPS(ph)PGPAQPGPR_
# 10          SAMD1  Phospho (STY)          _AAAAAAT(ph)APPSPGPAQPGPR_
# 11          SAMD1  Phospho (STY)          _AAAAAATAPPS(ph)PGPAQPGPR_
# ...           ...            ...                                 ...
# 165468   ARHGEF35  Phospho (STY)      _YYS(ph)PCEEHPAETNQNEGAESGTIR_
# 165469    ARHGEF5  Phospho (STY)      _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165470    ARHGEF5  Phospho (STY)      _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165475     TMEM51  Phospho (STY)            _YYVPS(ph)YEEVMNTNYSEAR_
# 165476     TMEM51  Phospho (STY)            _YYVPS(ph)YEEVMNTNYSEAR_
#
# [131402 rows x 3 columns]

# %%
def has_high_phospho_probability(prob_str):
    # Extract all numbers within parentheses, 
    probabilities = re.findall(r'\((\d+\.\d+)\)', prob_str)
    
    # Convert strings to float and check if any value is greater than 0.85
    return any(float(prob) > 0.85 for prob in probabilities)

data = filtered_data[filtered_data['Phospho (STY) Probabilities'].apply(has_high_phospho_probability)]

print(data[['Gene Names', 'Modified sequence', 'Phospho (STY) Probabilities']])
# Out:
#        Gene Names               Modified sequence  \
# 9           SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 12          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 13          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 14          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 15          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# ...           ...                             ...
# 165467   ARHGEF35  _YYS(ph)PCEEHPAETNQNEGAESGTIR_
# 165468   ARHGEF35  _YYS(ph)PCEEHPAETNQNEGAESGTIR_
# 165469    ARHGEF5  _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165470    ARHGEF5  _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165476     TMEM51        _YYVPS(ph)YEEVMNTNYSEAR_
#
#                               Phospho (STY) Probabilities
# 9                      AAAAAAT(0.011)APPS(0.989)PGPAQPGPR
# 12                     AAAAAAT(0.005)APPS(0.995)PGPAQPGPR
# 13                     AAAAAAT(0.001)APPS(0.999)PGPAQPGPR
# 14                     AAAAAAT(0.001)APPS(0.999)PGPAQPGPR
# 15                     AAAAAAT(0.011)APPS(0.989)PGPAQPGPR
# ...                                                   ...
# 165467  Y(0.001)Y(0.001)S(0.997)PCEEHPAET(0.002)NQNEGA...
# 165468  Y(0.001)Y(0.001)S(0.957)PCEEHPAET(0.042)NQNEGA...
# 165469             YYS(0.061)PCEEHPAET(0.938)NQNEGSESGTIR
# 165470               YYS(0.03)PCEEHPAET(0.97)NQNEGSESGTIR
# 165476                   YYVPS(0.956)Y(0.043)EEVMNTNYSEAR
#
# [50410 rows x 3 columns]

# %%
def extract_modified_amino_acid(modified_seq):
    modified_amino_acids = re.findall(r'([A-Z])\(ph\)', modified_seq)  # Only match phosphorylation
    return [aa for aa in modified_amino_acids]


data['Amino Acid'] = data['Modified sequence'].apply(extract_modified_amino_acid)

print(data[['Gene Names', 'Modified sequence', 'Phospho (STY) Probabilities', 'Amino Acid']])
# Out:
#        Gene Names               Modified sequence  \
# 9           SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 12          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 13          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 14          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# 15          SAMD1      _AAAAAATAPPS(ph)PGPAQPGPR_
# ...           ...                             ...
# 165467   ARHGEF35  _YYS(ph)PCEEHPAETNQNEGAESGTIR_
# 165468   ARHGEF35  _YYS(ph)PCEEHPAETNQNEGAESGTIR_
# 165469    ARHGEF5  _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165470    ARHGEF5  _YYSPCEEHPAET(ph)NQNEGSESGTIR_
# 165476     TMEM51        _YYVPS(ph)YEEVMNTNYSEAR_
#
#                               Phospho (STY) Probabilities Amino Acid
# 9                      AAAAAAT(0.011)APPS(0.989)PGPAQPGPR        [S]
# 12                     AAAAAAT(0.005)APPS(0.995)PGPAQPGPR        [S]
# 13                     AAAAAAT(0.001)APPS(0.999)PGPAQPGPR        [S]
# 14                     AAAAAAT(0.001)APPS(0.999)PGPAQPGPR        [S]
# 15                     AAAAAAT(0.011)APPS(0.989)PGPAQPGPR        [S]
# ...                                                   ...        ...
# 165467  Y(0.001)Y(0.001)S(0.997)PCEEHPAET(0.002)NQNEGA...        [S]
# 165468  Y(0.001)Y(0.001)S(0.957)PCEEHPAET(0.042)NQNEGA...        [S]
# 165469             YYS(0.061)PCEEHPAET(0.938)NQNEGSESGTIR        [T]
# 165470               YYS(0.03)PCEEHPAET(0.97)NQNEGSESGTIR        [T]
# 165476                   YYVPS(0.956)Y(0.043)EEVMNTNYSEAR        [S]
#
# [50410 rows x 4 columns]
# /var/folders/1v/y_z33m9d25d2tszlfrvnp2300000gn/T/ipykernel_12697/3352352718.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amino Acid'] = data['Modified sequence'].apply(extract_modified_amino_acid)

# %%
def find_position_in_gene(dataset, seq_column, fasta_path):
    positions_dict = {}
    
    # Parse the FASTA file
    fasta_sequence = list(SeqIO.parse(open(fasta_path), "fasta"))
    
    # Iterate over rows in the dataset
    for i, row in dataset.iterrows():
        gene_sequence = row[seq_column]  # Get the sequence from the dataset
        
        for seq_record in fasta_sequence:
            # Check if the sequence is part of the gene in the FASTA record
            start_position = str(seq_record.seq).find(gene_sequence)
            
            # If a match is found, store the position
            if start_position != -1:
                positions_dict[row['Gene Names']] = start_position
                break  # Stop once the position is found for the first matching gene
    
    # Add the start positions to the dataset as a new column
    dataset['StartPosition'] = dataset['Gene Names'].map(positions_dict)
    return dataset

fasta_path = '/Users/maryamkoddus/Documents/maryam-ko-QMUL-MSc-Project/01_input_data/raw_data/UP000005640_9606.fasta'
data = find_position_in_gene(data, 'Sequence', fasta_path)

# Print the data with start positions
print(data[['Gene Names', 'Sequence', 'StartPosition']])
# Out:
#        Gene Names                  Sequence  StartPosition
# 9           SAMD1      AAAAAATAPPSPGPAQPGPR          150.0
# 12          SAMD1      AAAAAATAPPSPGPAQPGPR          150.0
# 13          SAMD1      AAAAAATAPPSPGPAQPGPR          150.0
# 14          SAMD1      AAAAAATAPPSPGPAQPGPR          150.0
# 15          SAMD1      AAAAAATAPPSPGPAQPGPR          150.0
# ...           ...                       ...            ...
# 165467   ARHGEF35  YYSPCEEHPAETNQNEGAESGTIR          181.0
# 165468   ARHGEF35  YYSPCEEHPAETNQNEGAESGTIR          181.0
# 165469    ARHGEF5  YYSPCEEHPAETNQNEGSESGTIR          181.0
# 165470    ARHGEF5  YYSPCEEHPAETNQNEGSESGTIR          181.0
# 165476     TMEM51        YYVPSYEEVMNTNYSEAR          128.0
#
# [50410 rows x 3 columns]
# /var/folders/1v/y_z33m9d25d2tszlfrvnp2300000gn/T/ipykernel_12697/2766028544.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['StartPosition'] = dataset['Gene Names'].map(positions_dict)

# %%
# Select the necessary columns: Gene Names, Modified Amino Acids, Sequence, and Reporter Intensity columns
columns_to_display = ['Gene Names', 'Amino Acid', 'StartPosition', 'Sequence'] + [col for col in data.columns if 'Reporter intensity' in col]

# Display the data with the selected columns
print(data[columns_to_display])
# Out:
#        Gene Names Amino Acid  StartPosition                  Sequence  \
# 9           SAMD1        [S]          150.0      AAAAAATAPPSPGPAQPGPR
# 12          SAMD1        [S]          150.0      AAAAAATAPPSPGPAQPGPR
# 13          SAMD1        [S]          150.0      AAAAAATAPPSPGPAQPGPR
# 14          SAMD1        [S]          150.0      AAAAAATAPPSPGPAQPGPR
# 15          SAMD1        [S]          150.0      AAAAAATAPPSPGPAQPGPR
# ...           ...        ...            ...                       ...
# 165467   ARHGEF35        [S]          181.0  YYSPCEEHPAETNQNEGAESGTIR
# 165468   ARHGEF35        [S]          181.0  YYSPCEEHPAETNQNEGAESGTIR
# 165469    ARHGEF5        [T]          181.0  YYSPCEEHPAETNQNEGSESGTIR
# 165470    ARHGEF5        [T]          181.0  YYSPCEEHPAETNQNEGSESGTIR
# 165476     TMEM51        [S]          128.0        YYVPSYEEVMNTNYSEAR
#
#         Reporter intensity 0  Reporter intensity 1  Reporter intensity 2  \
# 9                    58392.0               53344.0               65403.0
# 12                   14635.0               13538.0                   0.0
# 13                  183920.0              200440.0              236420.0
# 14                   28570.0               24923.0               35335.0
# 15                  124420.0              126320.0              152890.0
# ...                      ...                   ...                   ...
# 165467               22109.0               18449.0               20685.0
# 165468                   NaN                   NaN                   NaN
# 165469                   0.0                7199.0                6900.4
# 165470                8164.7                5857.9                8512.2
# 165476               12949.0               10895.0               15901.0
#
#         Reporter intensity 3  Reporter intensity 4  Reporter intensity 5  \
# 9                    71718.0                   0.0                449.38
# 12                   20225.0                1017.7                482.39
# 13                  227770.0               11130.0              18815.00
# 14                   34110.0                2442.2               1805.10
# 15                  172590.0                8819.3              12493.00
# ...                      ...                   ...                   ...
# 165467               17919.0               27444.0              13070.00
# 165468                   NaN                   NaN                   NaN
# 165469                9858.5               12174.0               8997.80
# 165470                8685.4               19816.0               9367.90
# 165476               13102.0                   0.0                716.49
#
#         Reporter intensity 6  Reporter intensity 7  Reporter intensity 8  \
# 9                    12057.0                3290.1                   0.0
# 12                       0.0                   0.0                   0.0
# 13                   26802.0               12602.0                2677.3
# 14                    4455.6                5117.2                2528.5
# 15                   31432.0               10993.0                4322.1
# ...                      ...                   ...                   ...
# 165467               36607.0               27642.0               21322.0
# 165468                   NaN                   NaN                   NaN
# 165469                5765.2               15867.0               12735.0
# 165470                9901.8               22979.0               19071.0
# 165476                   0.0                   0.0                   0.0
#
#         Reporter intensity 9
# 9                    47433.0
# 12                    7672.9
# 13                   77048.0
# 14                   23934.0
# 15                   51076.0
# ...                      ...
# 165467               18889.0
# 165468                   NaN
# 165469                3799.5
# 165470                5375.5
# 165476                   0.0
#
# [50410 rows x 14 columns]

# %%
# Filtering out semi-colons from 'Amino acid', 'Positions within proteins', and 'Gene names' columns
data = data[~data['Amino Acid'].str.contains(';', na=False)]
data = data[~data['Gene Names'].str.contains(';', na=False)]
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/maryam-ko-QMUL-MSc-Project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Amino Acids'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Filtering out semi-colons from 'Amino acid', 'Positions within proteins', and 'Gene names' columns
# ----> 2 data = data[~data['Amino Acids'].str.contains(';', na=False)]
#       3 data = data[~data['Gene Names'].str.contains(';', na=False)]
#       4 data
#
# File ~/Documents/maryam-ko-QMUL-MSc-Project/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Documents/maryam-ko-QMUL-MSc-Project/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Amino Acids'

# %%
# filter data
data['Sequence'] = data['Sequence'].str.replace('_', '')
data

# %%
def match_seq_to_genename(dataset, seq_column):
    '''
    Maps amino acid sequences to gene names using the loaded fasta file.
    
    args:
    =====
    dataset: <pd.Dataframe> with a column of amino acid sequences
    seq_column: <str> column name containing amino acid sequences
    
    out:
    ====
    dataset: <pd.Dataframe> with an additional column containing gene names
    '''    

    fasta_sequence = list(SeqIO.parse(open(f'/Users/maryamkoddus/Documents/maryam-ko-QMUL-MSc-Project/01_input_data/raw_data/UP000005640_9606.fasta'), "fasta"))
    
    
    gene_dict = {}
    
    # iterate over rows in seq_column
    for i in dataset[seq_column]:
        print(i)
        i_str = str(i)
        for seq_record in fasta_sequence:
            matches = re.findall(i_str, str(seq_record.seq))
            if matches:
                print(f"Match found for sequence: {seq_record}")
                gene_name_match = re.search(r"GN=(\w+)", seq_record.description)
                print('Gene name match:', gene_name_match)
                # gene_name_match = re.search("GN=(\w+)", seq_record.description)
                if gene_name_match:
                    gene_name = gene_name_match.group(1)
                    gene_dict[i] = gene_name
                    print(f"Match found: {i_str} -> {gene_name}")
                else: 
                    print(f"No gene name found in description for sequence: {i_str}")
    
    # map sequences to gene names           
    dataset['GeneName'] = dataset[seq_column].map(gene_dict) 
    print('Amino acid sequences matched to gene names.')
    return dataset

# %%
data = match_seq_to_genename(data, 'Sequence')

# %%
data['Phosphosite'] = data['Amino Acids'].astype(str) + '(' + data['StartPosition'].astype(str) + ')'

# %%
keepcols = ['Phosphosite'] + ['GeneName'] + [col for col in data.columns if 'Reporter intensity' in col]
data = data[keepcols]
data

# %%
Intensity_columns = [col for col in data.columns if 'Reporter intensity' in col]
data[Intensity_columns] = data[Intensity_columns].apply(pd.to_numeric, errors='coerce')

# %%
def log2_transform(dataset):
    '''
    Log2 transform a dataset.
    
    args:
    =====
    dataset: <pd.Dataframe>
    
    out:
    ====
    dataset: <pd.Dataframe> with log2 transformed values

    '''
    cols_to_transform = dataset[Intensity_columns]
    dataset[Intensity_columns] = cols_to_transform.apply(np.log2)
    print('Data has been log2 transformed.')
    return dataset

# %%
data = log2_transform(data)
print(f"DataFrame after log2 transformation:\n{data}") # Print the DataFrame after log2 transformation
data

# %%
def create_phos_ID(dataset):
    '''
    Concatenates GeneName and Phosphosite columns.
    
    args:
    =====
    dataset: <pd.Dataframe> with columns 'GeneName' and 'Phosphosite'
    
    out:
    ====
    dataset: <pd.Dataframe> with 'phosphosite_ID' column and 'GeneName' + 'Phosphosite' columns dropped
    '''
    dataset.loc[:, 'phosphosite_ID'] = dataset['GeneName'].astype(str) + '_' + dataset['Phosphosite'].astype(str)
    dataset = dataset.drop(columns=['Phosphosite', 'GeneName'])
    print('Phosphosite IDs created.')
    return dataset

data = create_phos_ID(data) # call function to create phosphosite_ID column

print('Phosphosite IDs created.')

# %%
def clean_phosID_col(data):
    data = data[~data.phosphosite_ID.str.contains('nan', case=False, na=False)]
    data = data[~data.phosphosite_ID.str.contains(';', case=False, na=False)]
    data = data[~data.phosphosite_ID.str.contains('-', case=False, na=False)]

    # Add this line to remove decimals from phosphosite_ID (e.g., S123.0 -> S123)
    data['phosphosite_ID'] = data['phosphosite_ID'].apply(lambda x: re.sub(r'\((\d+)\.0+\)', r'(\1)', x))
    
    data_grouped = data.groupby(by='phosphosite_ID')
    
    if len(data) != len(data_grouped):
        numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
        non_numeric_cols = data.columns.difference(numeric_cols + ['phosphosite_ID']).tolist()
        data_numeric = data_grouped[numeric_cols].mean()
        data_categorical = data_grouped[non_numeric_cols].first().reset_index()
        
        # Merge numeric and non-numeric parts
        data = pd.merge(data_categorical, data_numeric, on='phosphosite_ID')
        print('Phosphosites with multiple measurements have been averaged')
    else:
        print('There are no phosphosites with multiple measurements')

    # Replace inf values with NaNs
    data = data.replace([np.inf, -np.inf], np.nan)
    
    # Ensure phosphosite_ID is first column
    if data.columns[0] != 'phosphosite_ID':
        phosphosite_ID = data.pop('phosphosite_ID')
        data.insert(0, 'phosphosite_ID', phosphosite_ID)

    return data

# %%
data = clean_phosID_col(data)
print("After cleaning phosphosite_ID column:")
data

# %%
data.to_csv(f'/Users/maryamkoddus/Documents/maryam-ko-QMUL-MSc-Project/01_input_data/PreprocessedDatasets/HH2022.csv', index=False)


print(dataset, 'has been saved to CSV successfully!', data)
